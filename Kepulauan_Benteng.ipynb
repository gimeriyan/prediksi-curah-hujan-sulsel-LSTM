# %%
import pandas as pd
import numpy as np
import joblib
import os
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.losses import Huber
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Membaca dataset master
df = pd.read_csv('CH_Master_10Tahun_2015_2024.csv', delimiter=';')

# Mendefinisikan df_stasiun (Inilah variabel yang dicari oleh sistem)
df_stasiun = df[df['NAME'] == 'Benteng / Bontoharu'].copy()

# %%
# ==========================================================
# 1. KONFIGURASI MODEL HARIAN
# ==========================================================
STASIUN = 'Benteng / Bontoharu' 
LOOK_BACK = 30      # Membaca data 30 HARI ke belakang
LOOK_AHEAD = 30    
LSTM_UNITS = 128     # Diperbesar sedikit karena data harian lebih rumit
EPOCHS = 100
BATCH_SIZE = 8    # Diperbesar karena jumlah data mencapai ribuan baris

print(f"🚀 MEMULAI PIPELINE HARIAN UNTUK: {STASIUN}")
if not os.path.exists('Hasil_Eksperimen'): os.makedirs('Hasil_Eksperimen')
# Out:
# 🚀 MEMULAI PIPELINE HARIAN UNTUK: Benteng / Bontoharu

# %%
# ==========================================================
# 2. FEATURE ENGINEERING (MENAMBAH FITUR BULAN)
# ==========================================================

print("\n[1/6] Membaca Dataset Master dan Membersihkan Data...")
df_all = pd.read_csv('CH_Master_10Tahun_2015_2024.csv', delimiter=';')
df_stasiun = df_all[df_all['NAME'] == STASIUN].copy()

# Pastikan urutan waktu benar (Sangat fatal untuk sekuensial harian)
df_stasiun['DATA TIMESTAMP'] = pd.to_datetime(df_stasiun['DATA TIMESTAMP'])
df_stasiun = df_stasiun.sort_values('DATA TIMESTAMP').reset_index(drop=True)

# Cleansing: Ubah 8888 dan 9999 jadi NaN
df_stasiun['RAINFALL DAY MM'] = df_stasiun['RAINFALL DAY MM'].replace(8888.0,0.0)
df_stasiun['RAINFALL DAY MM'] = df_stasiun['RAINFALL DAY MM'].replace(9999.0, np.nan)
df_stasiun['RAINFALL DAY MM'] = df_stasiun['RAINFALL DAY MM'].interpolate(method='linear')
df_stasiun['RAINFALL DAY MM'] = df_stasiun['RAINFALL DAY MM'].fillna(0.0) 

# TRIK BARU: Ekstrak Bulan (1-12) sebagai fitur tambahan pendamping hujan
df_stasiun['Bulan'] = df_stasiun['DATA TIMESTAMP'].dt.month

# Sekarang dataset kita punya 2 kolom fitur (Multivariat Semu)
fitur_pilihan = ['RAINFALL DAY MM', 'Bulan']
# Out:
# [1/6] Membaca Dataset Master dan Membersihkan Data...

# %%
# ==========================================================
# 3. PEMBAGIAN DATA (SEKUENSENSIAL HARIAN) & NORMALISASI
# ==========================================================
print("[2/6] Membagi Data berurutan: 60% Train dan 40% Test...")
total_data = len(df_stasiun)
batas_split = int(total_data * 0.60)

train_data = df_stasiun.iloc[:batas_split].copy()
test_data = df_stasiun.iloc[batas_split:].copy()

print(f"      -> Total Data Harian : {total_data} Hari")
print(f"      -> Data Train (60%)  : {len(train_data)} Hari")
print(f"      -> Data Test (40%)   : {len(test_data)} Hari")

scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train_data[['RAINFALL DAY MM']].values)
test_scaled = scaler.transform(test_data[['RAINFALL DAY MM']].values)
joblib.dump(scaler, f'Hasil_Eksperimen/scaler_harian_{STASIUN.replace(" / ", "_")}.pkl')
# Out:
# [2/6] Membagi Data berurutan: 60% Train dan 40% Test...
#       -> Total Data Harian : 3653 Hari
#       -> Data Train (60%)  : 2191 Hari
#       -> Data Test (40%)   : 1462 Hari
# ['Hasil_Eksperimen/scaler_harian_Benteng_Bontoharu.pkl']

# %%
# ==========================================================
# 4. PEMBENTUKAN SEQUENCE MULTIVARIAT (AGAK BERBEDA SEDIKIT)
# ==========================================================
def create_multivariate_dataset(dataset, look_back, look_ahead):
    X, Y = [], []
    for i in range(len(dataset) - look_back - look_ahead + 1):
        # X mengambil semua kolom (Hujan dan Bulan)
        X.append(dataset[i:(i + look_back), :])
        # Y HANYA mengambil kolom Hujan (indeks 0) sebagai target
        Y.append(dataset[(i + look_back):(i + look_back + look_ahead), 0])
    return np.array(X), np.array(Y)

X_train, y_train = create_multivariate_dataset(train_scaled, LOOK_BACK, LOOK_AHEAD)
X_test, y_test = create_multivariate_dataset(test_scaled, LOOK_BACK, LOOK_AHEAD)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
# ==========================================================
# 5. PELATIHAN MODEL LSTM
# ==========================================================
print(f"\n[4/6] Melatih Model Harian (Maks Epochs: {EPOCHS})...")
model = Sequential()
model.add(LSTM(units=LSTM_UNITS, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(units=LSTM_UNITS, return_sequences=True, input_shape=(LOOK_BACK, 1)))
model.add(Dropout(0.4))
model.add(LSTM(units=LSTM_UNITS, return_sequences=False))
model.add(Dropout(0.4))
model.add(Dense(units=LOOK_AHEAD))

# Tetap pakai Huber Loss karena data harian sangat rentan nilai ekstrem (outliers)
model.compile(optimizer='adam', loss=Huber(delta=1.0))
early_stop = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1)
history = model.fit(X_train, y_train, 
                    epochs=EPOCHS, 
                    batch_size=BATCH_SIZE, 
                    validation_data=(X_test, y_test), 
                    verbose=1)

model.save(f'Hasil_Eksperimen/model_harian_{STASIUN.replace(" / ", "_")}.h5')
# Out:
# [4/6] Melatih Model Harian (Maks Epochs: 100)...
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 43s 103ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 2/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 25s 94ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 3/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 43s 101ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 4/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 27s 102ms/step - loss: 0.0031 - val_loss: 0.0024
# Epoch 5/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 41s 102ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 6/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 27s 99ms/step - loss: 0.0031 - val_loss: 0.0024
# Epoch 7/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 27s 102ms/step - loss: 0.0029 - val_loss: 0.0024
# Epoch 8/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 27s 100ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 9/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 27s 101ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 10/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 41s 101ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 11/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 27s 101ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 12/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 27s 100ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 13/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 27s 101ms/step - loss: 0.0029 - val_loss: 0.0024
# Epoch 14/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 28s 104ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 15/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 32s 121ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 16/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 33s 123ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 17/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 28s 105ms/step - loss: 0.0032 - val_loss: 0.0023
# Epoch 18/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 28s 105ms/step - loss: 0.0032 - val_loss: 0.0023
# Epoch 19/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 28s 103ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 20/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 28s 103ms/step - loss: 0.0032 - val_loss: 0.0024
# Epoch 21/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 28s 105ms/step - loss: 0.0031 - val_loss: 0.0023
# Epoch 22/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 27s 103ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 23/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 27s 102ms/step - loss: 0.0031 - val_loss: 0.0024
# Epoch 24/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 28s 103ms/step - loss: 0.0032 - val_loss: 0.0023
# Epoch 25/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 27s 102ms/step - loss: 0.0032 - val_loss: 0.0023
# Epoch 26/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 42s 105ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 27/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 29s 110ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 28/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 26s 98ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 29/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 42s 102ms/step - loss: 0.0031 - val_loss: 0.0024
# Epoch 30/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 40s 97ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 31/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 32s 119ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 32/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 35s 96ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 33/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 25s 94ms/step - loss: 0.0027 - val_loss: 0.0024
# Epoch 34/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 24s 90ms/step - loss: 0.0029 - val_loss: 0.0024
# Epoch 35/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 26s 99ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 36/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 23s 88ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 37/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 27s 99ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 38/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 44s 109ms/step - loss: 0.0031 - val_loss: 0.0024
# Epoch 39/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 33s 122ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 40/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 30s 114ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 41/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 25s 94ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 42/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 25s 95ms/step - loss: 0.0029 - val_loss: 0.0024
# Epoch 43/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 44/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 45/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 24s 91ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 46/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 49s 122ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 47/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 29s 109ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 48/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 26s 96ms/step - loss: 0.0029 - val_loss: 0.0024
# Epoch 49/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 29s 107ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 50/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 25s 95ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 51/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 30s 112ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 52/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 26s 99ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 53/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 26s 97ms/step - loss: 0.0029 - val_loss: 0.0024
# Epoch 54/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 32s 119ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 55/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 41s 119ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 56/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 27s 103ms/step - loss: 0.0027 - val_loss: 0.0024
# Epoch 57/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 42s 105ms/step - loss: 0.0029 - val_loss: 0.0023
# Epoch 58/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 30s 113ms/step - loss: 0.0029 - val_loss: 0.0024
# Epoch 59/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 34s 127ms/step - loss: 0.0027 - val_loss: 0.0024
# Epoch 60/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 38s 116ms/step - loss: 0.0027 - val_loss: 0.0024
# Epoch 61/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 33s 122ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 62/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 26s 98ms/step - loss: 0.0029 - val_loss: 0.0024
# Epoch 63/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 26s 99ms/step - loss: 0.0029 - val_loss: 0.0024
# Epoch 64/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 44s 110ms/step - loss: 0.0028 - val_loss: 0.0024
# Epoch 65/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 32s 119ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 66/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 28s 104ms/step - loss: 0.0029 - val_loss: 0.0024
# Epoch 67/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 26s 99ms/step - loss: 0.0026 - val_loss: 0.0024
# Epoch 68/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 27s 100ms/step - loss: 0.0029 - val_loss: 0.0024
# Epoch 69/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 29s 108ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 70/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 32s 119ms/step - loss: 0.0029 - val_loss: 0.0025
# Epoch 71/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 42s 122ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 72/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 43s 129ms/step - loss: 0.0027 - val_loss: 0.0032
# Epoch 73/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 32s 93ms/step - loss: 0.0029 - val_loss: 0.0025
# Epoch 74/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 30s 114ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 75/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 26s 96ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 76/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 37s 138ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 77/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 27s 100ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 78/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 25s 92ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 79/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 26s 97ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 80/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 28s 105ms/step - loss: 0.0024 - val_loss: 0.0028
# Epoch 81/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 30s 111ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 82/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 39s 104ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 83/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 26s 96ms/step - loss: 0.0024 - val_loss: 0.0026
# Epoch 84/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 25s 94ms/step - loss: 0.0023 - val_loss: 0.0028
# Epoch 85/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 42s 98ms/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 86/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 26s 97ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 87/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 27s 99ms/step - loss: 0.0023 - val_loss: 0.0031
# Epoch 88/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 26s 96ms/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 89/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 25s 95ms/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 90/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 25s 93ms/step - loss: 0.0020 - val_loss: 0.0027
# Epoch 91/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 25s 92ms/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 92/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 41s 94ms/step - loss: 0.0022 - val_loss: 0.0028
# Epoch 93/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 25s 93ms/step - loss: 0.0019 - val_loss: 0.0026
# Epoch 94/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 25s 93ms/step - loss: 0.0020 - val_loss: 0.0029
# Epoch 95/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 27s 101ms/step - loss: 0.0019 - val_loss: 0.0028
# Epoch 96/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 31s 114ms/step - loss: 0.0019 - val_loss: 0.0028
# Epoch 97/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 30s 114ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 98/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 35s 132ms/step - loss: 0.0019 - val_loss: 0.0028
# Epoch 99/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 38s 120ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 100/100
# 267/267 ━━━━━━━━━━━━━━━━━━━━ 31s 118ms/step - loss: 0.0019 - val_loss: 0.0030
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# ==========================================================
# 6. EVALUASI METRIK AKHIR
# ==========================================================
print("\n[5/6] Menghitung Metrik Evaluasi Akhir...")

pred_train_scaled = model.predict(X_train, verbose=0)
pred_test_scaled = model.predict(X_test, verbose=0)

y_train_asli = scaler.inverse_transform(y_train)
pred_train_asli = scaler.inverse_transform(pred_train_scaled)
y_test_asli = scaler.inverse_transform(y_test)
pred_test_asli = scaler.inverse_transform(pred_test_scaled)

def print_metrik(y_true, y_pred, label_dataset):
    print(f"\n{'='*40}")
    print(f"📊 HASIL EVALUASI {label_dataset}")
    print(f"{'='*40}")
    mse = mean_squared_error(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    print(f"MSE  : {mse:.4f}")
    print(f"MAE  : {mae:.4f} mm / hari")
    print(f"R²   : {r2:.4f}")

print_metrik(y_train_asli, pred_train_asli, "DATA TRAIN HARIAN (60%)")
print_metrik(y_test_asli, pred_test_asli, "DATA TEST HARIAN (40%)")
# Out:
# [5/6] Menghitung Metrik Evaluasi Akhir...
#
# ========================================
# 📊 HASIL EVALUASI DATA TRAIN HARIAN (60%)
# ========================================
# MSE  : 109.0634
# MAE  : 5.7953 mm / hari
# R²   : 0.5193
#
# ========================================
# 📊 HASIL EVALUASI DATA TEST HARIAN (40%)
# ========================================
# MSE  : 213.4335
# MAE  : 8.0127 mm / hari
# R²   : -0.2526

# %%
# ==========================================
# 7. EVALUASI MODEL (FASE UJIAN SESUNGGUHNYA)
# ==========================================

# 1. DI BARIS INILAH DROPOUT OTOMATIS MATI (100% Neuron Menyala)
pred_test_scaled = model.predict(X_test) 

# 2. Mengembalikan skala angka (dari 0-1 menjadi angka milimeter curah hujan)
pred_test_asli = scaler.inverse_transform(pred_test_scaled)
y_test_asli = scaler.inverse_transform(y_test)
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step

# %%
# ==========================================================
# 8. VISUALISASI GRAFIK
# ==========================================================
# ==========================================
# GRAFIK 1: KURVA PENURUNAN ERROR (LOSS CURVE)
# ==========================================
plt.figure(figsize=(7, 4)) # Mengatur ukuran kanvas grafik loss

# Plot loss training dan validation
plt.plot(history.history['loss'], label='Huber Loss (Training)', color='blue', linewidth=2)
plt.plot(history.history['val_loss'], label='Huber Loss (Validation)', color='red', linewidth=2)

plt.title('Kurva Penurunan Error Harian (Benteng / Bontoharu)', fontsize=12, fontweight='bold')
plt.xlabel('Epochs', fontsize=10)
plt.ylabel('Loss Value', fontsize=10)
plt.legend(loc='upper right')
plt.grid(True, linestyle='--', alpha=0.6)

# Otomatis menyimpan grafik menjadi file gambar PNG berkualitas tinggi
plt.savefig('loss_benteng.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# ==========================================
# GRAFIK 2: AKTUAL VS PREDIKSI (DATA TESTING)
# ==========================================
plt.figure(figsize=(10, 4)) # Kanvas dibuat lebih lebar agar deret waktu terlihat jelas

# Menampilkan 100 hari pertama dari data pengujian agar tidak terlalu padat
plt.plot(y_test_asli[:100, 0], label='Aktual (BMKG)', color='blue', marker='.', alpha=0.7, linewidth=1.5)
plt.plot(pred_test_asli[:100, 0], label='Prediksi LSTM Harian', color='red', marker='x', alpha=0.9, linewidth=1.5)

plt.title('Grafik Aktual vs Prediksi (100 Hari Pertama di Data Test) -Benteng / Bontoharu', fontsize=12, fontweight='bold')
plt.xlabel('Waktu (Hari ke-)', fontsize=10)
plt.ylabel('Curah Hujan (mm)', fontsize=10)
plt.legend(loc='upper right')
plt.grid(True, linestyle='--', alpha=0.6)

# Otomatis menyimpan grafik menjadi file gambar PNG berkualitas tinggi
plt.savefig('eval_benteng.png', dpi=300, bbox_inches='tight')
plt.show()
